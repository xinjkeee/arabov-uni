# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from math import sin, cos
def func1(a, b, x):
    return a*(b-x) + x*(a+b) / (5*a + 5*x) if 5*a + 5*x != 0 else None
def func2(x):
    return sin(x)/cos(x) + cos(x)/(1+sin(x)) if (cos(x) != 0 and 1+sin(x) != 0) else None

def func3(a, b, gamma):
    return a**2 + b**2 - 2*a*b*cos(gamma)
def func4(a):
    last_num = 0
    a_copy = a
    count = 0
    while a > 0:
        last_num = a % 10
        a //= 10
        count += 1
    a_copy = a_copy * 10 + last_num
    a_copy = a_copy % (10**count)
    return a_copy

def func5(a):
    return a % 2 == 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def func1(x):
    if x >= -3.5:
        return 4*x**2 + 2 * x - 19
    else:
        return - (2 * x / (-4*x + 1))
    
def func2(a, b, c):
    return (a == b == c) and (a + b > c or a + c > b or b + c > a)

def func3(A, B, X, Y, Z):
    return (A >= X and B >= Y) or (A >= Y and B >= X)

def func4(S_cl, S_tr):
        pass
        ???

def func5(a, b, c, d, case):
    if case == 1:
         return abs(a - c) == 1 and abs(b - d) == 1
    if case == 2:
         return abs(a-c) == abs(b-d)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import isprime

def func1():
    def is_prime(n):
        if n <= 1:
            return False
        for i in range(2, int(n ** 0.5) + 1):
            if n % i == 0: 
                return False
        return True
    arr = []
    for i in range(1, 37):
        number = (2 ** (2 * i + 1) + 1) // 3
        if isprime(number):
            print(number)
    return arr
def func2():
    res = 1 + sin(0.1)
    for i in range(2, 101):
        res *= (1 + sin(i/10))
    return res
def func3():
    a_n = 2
    n = 1
    sum = a_n
    while a_n >= 10**(-3):
        a_n = 2 / (n + 1)
        n += 1
        sum += a_n
    return sum

def func4():
    a = int(input())
    sum = 0
    while a != 0:
        sum += a if a % 2 == 0 and a > 0 else 0
        a = int(input())
    return sum

func1()
# Out:
# 3
# 11
# 43
# 683
# 2731
# 43691
# 174763
# 2796203
# 715827883
# 2932031007403
# 768614336404564651
# []

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def func1():
    arr = []
    for a in range(1, 10):
        for b in range(10):
            for c in range(10):
                for d in range(10):
                    if a != b != c != d:
                        arr.append(a*1000+b*100+c*10+d)
    return arr

def func1_5():
    arr = []
    for a in range(1, 10):
        for b in range(10):
            for c in range(10):
                for d in range(10):
                    if a*b - c*d == a + b + c + d:
                        arr.append(a*1000+b*100+c*10+d)
    return arr

def func2(A, B, C, D):
    result_a = A * C
    result_b = B * D
    result = 0
    while result_a >= result_b:
        result_a -= result_b
        result += 1
    return f"{result}, {result_a}/{result_b}"

def func3(n):
    def fact(n):
        result = 1
        while n > 0:
            result *= n
            n -= 1
        return result
    summ = sum(fact(i) for i in range(1, n+1))
    return summ
# Out:
# 153
